# %% [markdown]
# ## THỰC HÀNH SỐ 1
# ---
# **Yêu cầu 1.1: Học viên đọc dữ liệu dạng CSV lưu trong file csv_Data_Loan.csv với các tham số mặc định, cho biết các thông tin cơ bản của file**

# %%
import numpy as np
import pandas as pd

# %%
#{HỌC VIÊN VIẾT CODE VÀO ĐÂY}
path_loan = 'Data/csv_Data_Loan.csv'
df_loan = pd.read_csv(path_loan)

df_loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113680 entries, 0 to 113679
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   loan_amnt       113680 non-null  int64
#  1   term            113680 non-null  object
#  2   int_rate        113680 non-null  float64
#  3   home_ownership  113680 non-null  object
#  4   annual_inc      113676 non-null  float64
#  5   purpose         113680 non-null  object
#  6   addr_state      113680 non-null  object
#  7   bad_loan        113680 non-null  int64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 6.9+ MB

# %%
df_loan.head()
# Out:
#    loan_amnt       term  int_rate home_ownership  annual_inc         purpose  \
# 0       5000  36 months     10.65           RENT     24000.0     credit_card
# 1       2500  60 months     15.27           RENT     30000.0             car
# 2       2400  36 months     15.96           RENT     12252.0  small_business
# 3      10000  36 months     13.49           RENT     49200.0           other
# 4       5000  36 months      7.90           RENT     36000.0         wedding
#
#   addr_state  bad_loan
# 0         AZ         0
# 1         GA         1
# 2         IL         0
# 3         CA         0
# 4         AZ         0

# %%
df_loan.tail()
# Out:
#         loan_amnt       term  int_rate home_ownership  annual_inc  \
# 113675      15000  60 months     12.39       MORTGAGE     45000.0
# 113676      20000  36 months     14.99            OWN     80000.0
# 113677      12825  36 months     17.14       MORTGAGE     38000.0
# 113678      27650  60 months     21.99           RENT     60000.0
# 113679      17000  60 months     15.99       MORTGAGE     63078.0
#
#                    purpose addr_state  bad_loan
# 113675         credit_card         OK         0
# 113676    home_improvement         VA         0
# 113677  debt_consolidation         TX         0
# 113678         credit_card         NY         0
# 113679  debt_consolidation         PA         0

# %% [markdown]
# **Yêu cầu 1.2: Đọc dữ liệu từ file Data_Loan.CSV vào 2 biến DataFrame tương ứng**
# 1. df_number: Chỉ chứa các cột dữ liệu số
# 2. df_object: Chỉ chứa các cột dữ liệu Object

# %%
#{HỌC VIÊN VIẾT CODE VÀO ĐÂY}

path_loan = 'Data/csv_Data_Loan.csv'
df_Loan = pd.read_csv(path_loan)

df_Loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113680 entries, 0 to 113679
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   loan_amnt       113680 non-null  int64
#  1   term            113680 non-null  object
#  2   int_rate        113680 non-null  float64
#  3   home_ownership  113680 non-null  object
#  4   annual_inc      113676 non-null  float64
#  5   purpose         113680 non-null  object
#  6   addr_state      113680 non-null  object
#  7   bad_loan        113680 non-null  int64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 6.9+ MB

# %%
cols_num = ['loan_amnt', 'int_rate', 'annual_inc', 'bad_loan']

df_number = pd.read_csv(path_loan, usecols = cols_num)

df_number.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113680 entries, 0 to 113679
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   loan_amnt   113680 non-null  int64
#  1   int_rate    113680 non-null  float64
#  2   annual_inc  113676 non-null  float64
#  3   bad_loan    113680 non-null  int64
# dtypes: float64(2), int64(2)
# memory usage: 3.5 MB

# %%
cols_obj = ['term', 'home_ownership', 'purpose', 'addr_state']

df_object = pd.read_csv(path_loan, usecols = cols_obj)

df_object.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113680 entries, 0 to 113679
# Data columns (total 4 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   term            113680 non-null  object
#  1   home_ownership  113680 non-null  object
#  2   purpose         113680 non-null  object
#  3   addr_state      113680 non-null  object
# dtypes: object(4)
# memory usage: 3.5+ MB

# %% [markdown]
# **Yêu cầu 1.3: Đọc dữ liệu nhiệt độ của 6 thành phố [Hà Nội, Vinh, Đà Nẵng, Nha Trang, TP Hồ Chí Minh, Cà Mau] từ file txt_Data_Temp.txt vào biến DataFrame tương ứng**

# %%
#{HỌC VIÊN VIẾT CODE VÀO ĐÂY}

path_temp = 'Data/txt_Data_Temp.txt'

df_temp = pd.read_csv(path_temp,
                      sep = ' ',
                      names = ['Hà Nội', 'Vinh', 'Đà Nẵng', 'Nha Trang', 'TP Hồ Chí Minh', 'Cà Mau'])

df_temp.info()

# %%
df_temp.head()

# %%
df_temp.tail()

# %% [markdown]
# ## THỰC HÀNH 3.2
# ---
# Yêu cầu: Học viên đọc dữ liệu dạng excel lưu trong file excel_Data_Movies.xls theo từng sheet

# %%
#{HỌC VIÊN VIẾT CODE Ở ĐÂY}

path_movies = 'Data\excel_Data_Movies.xls'

data_movies_1900s = pd.read_excel(path_movies,
                                  sheet_name = '1900s')

data_movies_1900s.info()

data_movies_1900s.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Title                        1338 non-null   object
#  1   Year                         1338 non-null   int64
#  2   Genres                       1338 non-null   object
#  3   Language                     1334 non-null   object
#  4   Country                      1338 non-null   object
#  5   Content Rating               1316 non-null   object
#  6   Duration                     1338 non-null   int64
#  7   Aspect Ratio                 1308 non-null   float64
#  8   Budget                       1281 non-null   float64
#  9   Gross Earnings               1086 non-null   float64
#  10  Director                     1338 non-null   object
#  11  Actor 1                      1338 non-null   object
#  12  Actor 2                      1338 non-null   object
#  13  Actor 3                      1336 non-null   object
#  14  Facebook Likes - Director    1338 non-null   int64
#  15  Facebook Likes - Actor 1     1338 non-null   int64
#  16  Facebook Likes - Actor 2     1338 non-null   int64
#  17  Facebook Likes - Actor 3     1336 non-null   float64
#  18  Facebook Likes - cast Total  1338 non-null   int64
#  19  Facebook likes - Movie       1338 non-null   int64
#  20  Facenumber in posters        1338 non-null   int64
#  21  User Votes                   1338 non-null   int64
#  22  Reviews by Users             1338 non-null   int64
#  23  Reviews by Crtiics           1335 non-null   float64
#  24  IMDB Score                   1338 non-null   float64
# dtypes: float64(6), int64(10), object(9)
# memory usage: 261.5+ KB
#                                                Title  Year  \
# 0  Intolerance: Love's Struggle Throughout the Ages   1916
# 1                    Over the Hill to the Poorhouse   1920
# 2                                    The Big Parade   1925
# 3                                        Metropolis   1927
# 4                                     Pandora's Box   1929
#
#                 Genres Language  Country Content Rating  Duration  \
# 0    Drama|History|War      NaN      USA      Not Rated       123
# 1          Crime|Drama      NaN      USA            NaN       110
# 2    Drama|Romance|War      NaN      USA      Not Rated       151
# 3         Drama|Sci-Fi   German  Germany      Not Rated       145
# 4  Crime|Drama|Romance   German  Germany      Not Rated       110
#
#    Aspect Ratio     Budget  Gross Earnings  ... Facebook Likes - Actor 1  \
# 0          1.33   385907.0             NaN  ...                      436
# 1          1.33   100000.0       3000000.0  ...                        2
# 2          1.33   245000.0             NaN  ...                       81
# 3          1.33  6000000.0         26435.0  ...                      136
# 4          1.33        NaN          9950.0  ...                      426
#
#   Facebook Likes - Actor 2 Facebook Likes - Actor 3  \
# 0                       22                      9.0
# 1                        2                      0.0
# 2                       12                      6.0
# 3                       23                     18.0
# 4                       20                      3.0
#
#   Facebook Likes - cast Total  Facebook likes - Movie  Facenumber in posters  \
# 0                         481                     691                      1
# 1                           4                       0                      1
# 2                         108                     226                      0
# 3                         203                   12000                      1
# 4                         455                     926                      1
#
#    User Votes  Reviews by Users  Reviews by Crtiics  IMDB Score
# 0       10718                88                69.0         8.0
# 1           5                 1                 1.0         4.8
# 2        4849                45                48.0         8.3
# 3      111841               413               260.0         8.3
# 4        7431                84                71.0         8.0
#
# [5 rows x 25 columns]

# %%
data_movies_2000s = pd.read_excel(path_movies,
                                  skiprows = 3,
                                  sheet_name = '2000s')

data_movies_2000s.info()

data_movies_2000s.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2100 entries, 0 to 2099
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Title                        2100 non-null   object
#  1   Year                         2100 non-null   int64
#  2   Genres                       2100 non-null   object
#  3   Language                     2098 non-null   object
#  4   Country                      2100 non-null   object
#  5   Content Rating               2013 non-null   object
#  6   Duration                     2096 non-null   float64
#  7   Aspect Ratio                 2033 non-null   float64
#  8   Budget                       1920 non-null   float64
#  9   Gross Earnings               1928 non-null   float64
#  10  Director                     2100 non-null   object
#  11  Actor 1                      2097 non-null   object
#  12  Actor 2                      2097 non-null   object
#  13  Actor 3                      2092 non-null   object
#  14  Facebook Likes - Director    2100 non-null   int64
#  15  Facebook Likes - Actor 1     2097 non-null   float64
#  16  Facebook Likes - Actor 2     2097 non-null   float64
#  17  Facebook Likes - Actor 3     2092 non-null   float64
#  18  Facebook Likes - cast Total  2100 non-null   int64
#  19  Facebook likes - Movie       2100 non-null   int64
#  20  Facenumber in posters        2100 non-null   int64
#  21  User Votes                   2100 non-null   int64
#  22  Reviews by Users             2096 non-null   float64
#  23  Reviews by Crtiics           2087 non-null   float64
#  24  IMDB Score                   2100 non-null   float64
# dtypes: float64(10), int64(6), object(9)
# memory usage: 410.3+ KB
#                     Title  Year                   Genres Language Country  \
# 0         102 Dalmatians   2000  Adventure|Comedy|Family  English     USA
# 1                28 Days   2000             Comedy|Drama  English     USA
# 2              3 Strikes   2000                   Comedy  English     USA
# 3               Aberdeen   2000                    Drama  English      UK
# 4  All the Pretty Horses   2000    Drama|Romance|Western  English     USA
#
#   Content Rating  Duration  Aspect Ratio      Budget  Gross Earnings  ...  \
# 0              G     100.0          1.85  85000000.0      66941559.0  ...
# 1          PG-13     103.0          1.37  43000000.0      37035515.0  ...
# 2              R      82.0          1.85   6000000.0       9821335.0  ...
# 3            NaN     106.0          1.85   6500000.0         64148.0  ...
# 4          PG-13     220.0          2.35  57000000.0      15527125.0  ...
#
#   Facebook Likes - Actor 1 Facebook Likes - Actor 2 Facebook Likes - Actor 3  \
# 0                   2000.0                    795.0                    439.0
# 1                  12000.0                  10000.0                    664.0
# 2                    939.0                    706.0                    585.0
# 3                    844.0                      2.0                      0.0
# 4                  13000.0                    861.0                    820.0
#
#   Facebook Likes - cast Total  Facebook likes - Movie  Facenumber in posters  \
# 0                        4182                     372                      1
# 1                       23864                       0                      1
# 2                        3354                     118                      1
# 3                         846                     260                      0
# 4                       15006                     652                      2
#
#    User Votes  Reviews by Users  Reviews by Crtiics  IMDB Score
# 0       26413              77.0                84.0         4.8
# 1       34597             194.0               116.0         6.0
# 2        1415              10.0                22.0         4.0
# 3        2601              35.0                28.0         7.3
# 4       11388             183.0                85.0         5.8
#
# [5 rows x 25 columns]

# %%
data_movies_2010s = pd.read_excel(path_movies,
                                  skiprows = 3,
                                  sheet_name = '2010s', 
                                  names = list(data_movies_2000s.columns),
                                  header = None)

data_movies_2010s.info()

data_movies_2010s.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1604 entries, 0 to 1603
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Title                        1604 non-null   object
#  1   Year                         1497 non-null   float64
#  2   Genres                       1604 non-null   object
#  3   Language                     1599 non-null   object
#  4   Country                      1600 non-null   object
#  5   Content Rating               1411 non-null   object
#  6   Duration                     1594 non-null   float64
#  7   Aspect Ratio                 1373 non-null   float64
#  8   Budget                       1350 non-null   float64
#  9   Gross Earnings               1145 non-null   float64
#  10  Director                     1500 non-null   object
#  11  Actor 1                      1600 non-null   object
#  12  Actor 2                      1594 non-null   object
#  13  Actor 3                      1592 non-null   object
#  14  Facebook Likes - Director    1500 non-null   float64
#  15  Facebook Likes - Actor 1     1600 non-null   float64
#  16  Facebook Likes - Actor 2     1594 non-null   float64
#  17  Facebook Likes - Actor 3     1592 non-null   float64
#  18  Facebook Likes - cast Total  1604 non-null   int64
#  19  Facebook likes - Movie       1604 non-null   int64
#  20  Facenumber in posters        1591 non-null   float64
#  21  User Votes                   1604 non-null   int64
#  22  Reviews by Users             1588 non-null   float64
#  23  Reviews by Crtiics           1571 non-null   float64
#  24  IMDB Score                   1604 non-null   float64
# dtypes: float64(13), int64(3), object(9)
# memory usage: 313.4+ KB
#                                   Title    Year  \
# 0                            127 Hours   2010.0
# 1                          3 Backyards   2010.0
# 2                                    3   2010.0
# 3            8: The Mormon Proposition   2010.0
# 4  A Turtle's Tale: Sammy's Adventures   2010.0
#
#                                Genres Language  Country Content Rating  \
# 0  Adventure|Biography|Drama|Thriller  English      USA              R
# 1                               Drama  English      USA              R
# 2                Comedy|Drama|Romance   German  Germany        Unrated
# 3                         Documentary  English      USA              R
# 4          Adventure|Animation|Family  English   France             PG
#
#    Duration  Aspect Ratio      Budget  Gross Earnings  ...  \
# 0      94.0          1.85  18000000.0      18329466.0  ...
# 1      88.0           NaN    300000.0             NaN  ...
# 2     119.0          2.35         NaN         59774.0  ...
# 3      80.0          1.78   2500000.0         99851.0  ...
# 4      88.0          2.35         NaN             NaN  ...
#
#   Facebook Likes - Actor 1 Facebook Likes - Actor 2 Facebook Likes - Actor 3  \
# 0                  11000.0                    642.0                    223.0
# 1                    795.0                    659.0                    301.0
# 2                     24.0                     20.0                      9.0
# 3                    191.0                     12.0                      5.0
# 4                    783.0                    749.0                    602.0
#
#   Facebook Likes - cast Total  Facebook likes - Movie  Facenumber in posters  \
# 0                       11984                   63000                    0.0
# 1                        1884                      92                    0.0
# 2                          69                    2000                    0.0
# 3                         210                       0                    0.0
# 4                        3874                       0                    2.0
#
#    User Votes  Reviews by Users  Reviews by Crtiics  IMDB Score
# 0      279179             440.0               450.0         7.6
# 1         554              23.0                20.0         5.2
# 2        4212              18.0                76.0         6.8
# 3        1138              30.0                28.0         7.1
# 4        5385              22.0                56.0         6.1
#
# [5 rows x 25 columns]

# %% [markdown]
# ## THỰC HÀNH 3:
# ---
# **Mô tả file dữ liệu: Data_Patient.csv**
# * File dữ liệu chứa thông tin của 300 bệnh nhân bị chứng đau ngực
# * Mỗi dòng ứng với thông tin của một bệnh nhân, bao gồm 9 thuộc tính.
#
# **Chi tiết thông tin của một bệnh nhân như sau:**
# * id: Mã của bệnh nhân (số)
# * Feature_1: Tuổi của bệnh nhân (số)
# * Feature_2: Giới tính của bệnh nhân (chuỗi: Male – Female)
# * Feature_3: Cho biết loại triệu chứng đau ngực mà bệnh nhân này mắc phải, với 4 giá trị: (Typical angina, Atypical angina, Non-anginal pain, Asymptomatic)
# * Feature_4: Huyết áp của bệnh nhân – đơn vị: mmhg (số)
# * Feature_5: Chỉ số cholesterol của bệnh nhân – đơn vị: mg/dl (số)
# * Feature_6: Thông số nhịp tim của bệnh nhân – đơn vị: lần/phút (số)
# * Feature_7: Chỉ số Thalassemia của bệnh nhân chỉ gồm 3 giá trị (3: Bình thường | 4: Khiếm khuyết cố định | 7: Kiếm khuyết có thể đảo ngược)
# * Feature_8: Cho biết bệnh nhân có bị bệnh tim hay không? (0: Không bị bệnh tim mạch | 1: Bị bệnh tim mạch)

# %% [markdown]
# **Yêu cầu 3.1:**
# 1. Đọc dữ liệu từ file Data_Excercise\Data_patient.csv vào biến kiểu dataframe: df_patient với cột đầu tiên (id) là cột chỉ số (index_col)
# 2. Hiển thị thông tin tổng quan của tập dữ liệu
# 3. Hiển thị thông tin của 10 bệnh nhân đầu tiên và 5 bệnh nhân cuối cùng của tập dữ liệu.
# 4. Đặt lại tên các cột dữ liệu trong Dataframe:
#     * Feature_1 --> Age
#     * Feature_2 --> Gender
#     * Feature_3 --> Type
#     * Feature_4 --> Blood_pressure
#     * Feature_5 --> Cholesterol
#     * Feature_6 --> Heartbeat
#     * Feature_7 --> Thalassemia
#     * Feature_8 --> Result

# %%
#{VIẾT CODE CỦA BẠN VÀO ĐÂY}

path_patient = 'Data/Data_Patient.csv'
df_patient = pd.read_csv(path_patient, index_col = 0)

df_patient.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 300 entries, Patient_01 to Patient_300
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   feature_1  300 non-null    int64
#  1   feature_2  300 non-null    object
#  2   feature_3  295 non-null    object
#  3   feature_4  300 non-null    int64
#  4   feature_5  300 non-null    int64
#  5   feature_6  300 non-null    int64
#  6   feature_7  293 non-null    float64
#  7   feature_8  300 non-null    int64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 21.1+ KB

# %%
df_patient.head(10)
# Out:
#             feature_1 feature_2         feature_3  feature_4  feature_5  \
# id
# Patient_01         63      Male    Typical angina        145        233
# Patient_02         67      Male      Asymptomatic        160        286
# Patient_03         67      Male      Asymptomatic        120        229
# Patient_04         37      Male  Non-anginal pain        130        250
# Patient_05         41    Female   Atypical angina        130        204
# Patient_06         56      Male   Atypical angina        120        236
# Patient_07         62    Female      Asymptomatic        140        268
# Patient_08         57    Female      Asymptomatic        120        354
# Patient_09         63      Male      Asymptomatic        130        254
# Patient_10         53      Male      Asymptomatic        140        203
#
#             feature_6  feature_7  feature_8
# id
# Patient_01        150        6.0          0
# Patient_02        108        3.0          1
# Patient_03        129        7.0          1
# Patient_04        187        3.0          0
# Patient_05        172        NaN          0
# Patient_06        178        3.0          0
# Patient_07        160        3.0          1
# Patient_08        163        3.0          0
# Patient_09        147        7.0          1
# Patient_10        155        7.0          1

# %%
df_patient.tail()
# Out:
#              feature_1 feature_2       feature_3  feature_4  feature_5  \
# id
# Patient_296         59      Male    Asymptomatic        164        176
# Patient_297         57    Female    Asymptomatic        140        241
# Patient_298         45      Male  Typical angina        110        264
# Patient_299         68      Male    Asymptomatic        144        193
# Patient_300         57      Male    Asymptomatic        130        131
#
#              feature_6  feature_7  feature_8
# id
# Patient_296         90        6.0          1
# Patient_297        123        7.0          1
# Patient_298        132        7.0          1
# Patient_299        141        7.0          1
# Patient_300        115        7.0          1

# %%
#Đổi tên cột
col_name = {'feature_1':'Age',
            'feature_2':'Gender',
            'feature_3':'Type',
            'feature_4':'Blood_pressure',
            'feature_5':'Cholesterol',
            'feature_6':'Heartbeat',
            'feature_7':'Thalassemia',
            'feature_8':'Result'}

df_patient.rename(columns = col_name,
                  inplace = True)
df_patient.head()
# Out:
#             Age  Gender              Type  Blood_pressure  Cholesterol  \
# id
# Patient_01   63    Male    Typical angina             145          233
# Patient_02   67    Male      Asymptomatic             160          286
# Patient_03   67    Male      Asymptomatic             120          229
# Patient_04   37    Male  Non-anginal pain             130          250
# Patient_05   41  Female   Atypical angina             130          204
#
#             Heartbeat  Thalassemia  Result
# id
# Patient_01        150          6.0       0
# Patient_02        108          3.0       1
# Patient_03        129          7.0       1
# Patient_04        187          3.0       0
# Patient_05        172          NaN       0

# %% [markdown]
# **Yêu cầu 3.2:**
# Sử dụng phương thức .describe() cho biết:
#
#     * Thuộc tính Age:
#         - Tuổi của bệnh nhân trẻ nhất
#         - Tuổi của bệnh nhân già nhất
#     * Thuộc tính Cholesterol:
#         - Cholesterol trung bình của các bệnh nhân
#         - Độ lệch chuẩn của giá trị này trong toàn bộ tập dữ liệu
#     * Bao nhiêu bệnh nhân giới tính nam (Male)
#     * Có bao nhiêu giá trị khác nhau của thuộc tính Type. Giá trị xuất hiện nhiều nhất là giá trị nào, bao nhiêu lần.

# %%
#{VIẾT CODE CỦA BẠN VÀO ĐÂY}
print('Tuổi của bệnh nhân trẻ nhất:', df_patient['Age'].min())
print('Tuổi của bệnh nhân già nhất:', df_patient['Age'].max())
# Out:
# Tuổi của bệnh nhân trẻ nhất: 29
# Tuổi của bệnh nhân già nhất: 77

# %%
print('Cholesterol trung bình của các bệnh nhân:', df_patient['Cholesterol'].mean())

print('Độ lệch chuẩn của giá trị này:', df_patient['Cholesterol'].std())
# Out:
# Cholesterol trung bình của các bệnh nhân: 247.07
# Độ lệch chuẩn của giá trị này: 51.835136454315

# %%
print('Có', df_patient['Gender'].count(), 'bệnh nhân giới tính nam.')
# Out:
# Có 300 bệnh nhân giới tính nam.

# %%
print('Có', len(pd.unique(df_patient['Type'].dropna())), 'giá trị khác nhau của thuộc tính Type.')

print('Giá trị xuất hiện nhiều nhất là giá trị:', df_patient['Type'].value_counts())
# Out:
# Có 4 giá trị khác nhau của thuộc tính Type.
# Giá trị xuất hiện nhiều nhất là giá trị: Asymptomatic        139
# Non-anginal pain     84
# Atypical angina      49
# Typical angina       23
# Name: Type, dtype: int64

# %% [markdown]
# **Yêu cầu 3.3:**
#
# Cho biết những cột nào trong dữ liệu có chứa missing data và số lượng missing là bao nhiêu?

# %%
#{VIẾT CODE CỦA BẠN VÀO ĐÂY}

miss_data = df_patient.isna().sum()

print('Những cột chứa missing data:\n', miss_data[miss_data > 0])
# Out:
# Những cột chứa missing data:
#  Type           5
# Thalassemia    7
# dtype: int64

# %% [markdown]
# **Yêu cầu 3.4:**
# Hiển thị thông tin của các bệnh nhân:
#    * Bệnh nhân có index: Patient_100; Patient_150; Patient_200
#    * Bệnh nhân ở vị trí 255 đến 260, với 3 thuộc tính: Age, Gender và Result

# %%
#{VIẾT CODE CỦA BẠN VÀO ĐÂY}

df_patient.iloc[[99,149,199],:]
# Out:
#              Age  Gender            Type  Blood_pressure  Cholesterol  \
# id
# Patient_100   45    Male    Asymptomatic             115          260
# Patient_150   52    Male  Typical angina             152          298
# Patient_200   50  Female    Asymptomatic             110          254
#
#              Heartbeat  Thalassemia  Result
# id
# Patient_100        185          3.0       0
# Patient_150        178          7.0       0
# Patient_200        159          3.0       0

# %%
df_patient.loc['Patient_255':'Patient_260',['Age', 'Gender', 'Result']]
# Out:
#              Age  Gender  Result
# id
# Patient_255   42  Female       0
# Patient_256   67  Female       0
# Patient_257   76  Female       0
# Patient_258   70    Male       0
# Patient_259   57    Male       1
# Patient_260   44  Female       0

# %% [markdown]
# **Yêu cầu 3.5:**
# 1. Thay đổi giá trị cho thuộc tính Gender: Male --> 0, Female --> 1
# 2. Thay đổi giá trị cho thuộc tính Result: 0 --> No, 1 --> Yes
# 3. Cập nhật giá trị thuộc tính Thalassemia của bệnh nhân có index: Patient_05 bằng giá trị 4.0

# %%
#{VIẾT CODE CỦA BẠN VÀO ĐÂY}

gender_rplc = {'Male':0,
               'Female':1}

df_patient.replace(gender_rplc, inplace = True)
df_patient.head()
# Out:
#             Age  Gender              Type  Blood_pressure  Cholesterol  \
# id
# Patient_01   63       0    Typical angina             145          233
# Patient_02   67       0      Asymptomatic             160          286
# Patient_03   67       0      Asymptomatic             120          229
# Patient_04   37       0  Non-anginal pain             130          250
# Patient_05   41       1   Atypical angina             130          204
#
#             Heartbeat  Thalassemia  Result
# id
# Patient_01        150          6.0       0
# Patient_02        108          3.0       1
# Patient_03        129          7.0       1
# Patient_04        187          3.0       0
# Patient_05        172          NaN       0

# %%
result_rplc = {0:'No',
               1:'Yes'}
df_patient['Result'].replace(result_rplc, inplace = True)
df_patient.head()
# Out:
#             Age  Gender              Type  Blood_pressure  Cholesterol  \
# id
# Patient_01   63       0    Typical angina             145          233
# Patient_02   67       0      Asymptomatic             160          286
# Patient_03   67       0      Asymptomatic             120          229
# Patient_04   37       0  Non-anginal pain             130          250
# Patient_05   41       1   Atypical angina             130          204
#
#             Heartbeat  Thalassemia Result
# id
# Patient_01        150          6.0     No
# Patient_02        108          3.0    Yes
# Patient_03        129          7.0    Yes
# Patient_04        187          3.0     No
# Patient_05        172          NaN     No

# %%
df_patient.iloc[4,6] = 4.0
df_patient
# Out:
#              Age  Gender              Type  Blood_pressure  Cholesterol  \
# id
# Patient_01    63       0    Typical angina             145          233
# Patient_02    67       0      Asymptomatic             160          286
# Patient_03    67       0      Asymptomatic             120          229
# Patient_04    37       0  Non-anginal pain             130          250
# Patient_05    41       1   Atypical angina             130          204
# ...          ...     ...               ...             ...          ...
# Patient_296   59       0      Asymptomatic             164          176
# Patient_297   57       1      Asymptomatic             140          241
# Patient_298   45       0    Typical angina             110          264
# Patient_299   68       0      Asymptomatic             144          193
# Patient_300   57       0      Asymptomatic             130          131
#
#              Heartbeat  Thalassemia Result
# id
# Patient_01         150          6.0     No
# Patient_02         108          3.0    Yes
# Patient_03         129          7.0    Yes
# Patient_04         187          3.0     No
# Patient_05         172          4.0     No
# ...                ...          ...    ...
# Patient_296         90          6.0    Yes
# Patient_297        123          7.0    Yes
# Patient_298        132          7.0    Yes
# Patient_299        141          7.0    Yes
# Patient_300        115          7.0    Yes
#
# [300 rows x 8 columns]

# %% [markdown]
# # THỰC HÀNH 4:
# ---
# **Yêu cầu 4.1:**
# 1. Đọc dữ liệu từ file Data_Excercise\Data_patient.csv vào biến kiểu dataframe: df_patient với cột feature_1 là cột chỉ số (index_col)
# 2. Đặt lại tên các cột dữ liệu trong Dataframe:
#     * Feature_1 --> Age
#     * Feature_2 --> Gender
#     * Feature_3 --> Type
#     * Feature_4 --> Blood_pressure
#     * Feature_5 --> Cholesterol
#     * Feature_6 --> Heartbeat
#     * Feature_7 --> Thalassemia
#     * Feature_8 --> Result
#
#  *Như yêu cầu đã thực hiện trong bài thực hành số 3*

# %%
#{HỌC VIÊN VIẾT CODE VÀO ĐÂY}

path_patient = 'Data\Data_patient.csv'

df_patient = pd.read_csv(path_patient, index_col = 0)
df_patient
# Out:
#              feature_1 feature_2         feature_3  feature_4  feature_5  \
# id
# Patient_01          63      Male    Typical angina        145        233
# Patient_02          67      Male      Asymptomatic        160        286
# Patient_03          67      Male      Asymptomatic        120        229
# Patient_04          37      Male  Non-anginal pain        130        250
# Patient_05          41    Female   Atypical angina        130        204
# ...                ...       ...               ...        ...        ...
# Patient_296         59      Male      Asymptomatic        164        176
# Patient_297         57    Female      Asymptomatic        140        241
# Patient_298         45      Male    Typical angina        110        264
# Patient_299         68      Male      Asymptomatic        144        193
# Patient_300         57      Male      Asymptomatic        130        131
#
#              feature_6  feature_7  feature_8
# id
# Patient_01         150        6.0          0
# Patient_02         108        3.0          1
# Patient_03         129        7.0          1
# Patient_04         187        3.0          0
# Patient_05         172        NaN          0
# ...                ...        ...        ...
# Patient_296         90        6.0          1
# Patient_297        123        7.0          1
# Patient_298        132        7.0          1
# Patient_299        141        7.0          1
# Patient_300        115        7.0          1
#
# [300 rows x 8 columns]

# %%
#Đổi tên cột
col_name = {'feature_1':'Age',
            'feature_2':'Gender',
            'feature_3':'Type',
            'feature_4':'Blood_pressure',
            'feature_5':'Cholesterol',
            'feature_6':'Heartbeat',
            'feature_7':'Thalassemia',
            'feature_8':'Result'}

df_patient.rename(columns = col_name,
                  inplace = True)
df_patient.head()
# Out:
#             Age  Gender              Type  Blood_pressure  Cholesterol  \
# id
# Patient_01   63    Male    Typical angina             145          233
# Patient_02   67    Male      Asymptomatic             160          286
# Patient_03   67    Male      Asymptomatic             120          229
# Patient_04   37    Male  Non-anginal pain             130          250
# Patient_05   41  Female   Atypical angina             130          204
#
#             Heartbeat  Thalassemia  Result
# id
# Patient_01        150          6.0       0
# Patient_02        108          3.0       1
# Patient_03        129          7.0       1
# Patient_04        187          3.0       0
# Patient_05        172          NaN       0

# %% [markdown]
# **Yêu cầu 4.2:**
# Lọc dữ liệu trong df_patient thành các DataFrame:
#     * df_male: chứa danh sách bệnh nhân Nam
#     * df_female: chứa danh sách bệnh nhân nữ
#     * df_no: danh sách những người không bị bệnh đau tim
#     * df_yes: danh sách những người bị bệnh đau tim

# %%
#{HỌC VIÊN VIẾT CODE VÀO ĐÂY}

df_male = df_patient[df_patient['Gender'] == 'Male']
df_male.head()
# Out:
#             Age Gender              Type  Blood_pressure  Cholesterol  \
# id
# Patient_01   63   Male    Typical angina             145          233
# Patient_02   67   Male      Asymptomatic             160          286
# Patient_03   67   Male      Asymptomatic             120          229
# Patient_04   37   Male  Non-anginal pain             130          250
# Patient_06   56   Male   Atypical angina             120          236
#
#             Heartbeat  Thalassemia  Result
# id
# Patient_01        150          6.0       0
# Patient_02        108          3.0       1
# Patient_03        129          7.0       1
# Patient_04        187          3.0       0
# Patient_06        178          3.0       0

# %%
df_female = df_patient[df_patient['Gender'] == 'Female']
df_female.head()
# Out:
#             Age  Gender              Type  Blood_pressure  Cholesterol  \
# id
# Patient_05   41  Female   Atypical angina             130          204
# Patient_07   62  Female      Asymptomatic             140          268
# Patient_08   57  Female      Asymptomatic             120          354
# Patient_12   56  Female   Atypical angina             140          294
# Patient_19   48  Female  Non-anginal pain             130          275
#
#             Heartbeat  Thalassemia  Result
# id
# Patient_05        172          NaN       0
# Patient_07        160          3.0       1
# Patient_08        163          3.0       0
# Patient_12        153          3.0       0
# Patient_19        139          3.0       0

# %%
df_yes = df_patient[df_patient['Result'] == 1]
df_yes.head()
# Out:
#             Age  Gender          Type  Blood_pressure  Cholesterol  Heartbeat  \
# id
# Patient_02   67    Male  Asymptomatic             160          286        108
# Patient_03   67    Male  Asymptomatic             120          229        129
# Patient_07   62  Female  Asymptomatic             140          268        160
# Patient_09   63    Male  Asymptomatic             130          254        147
# Patient_10   53    Male  Asymptomatic             140          203        155
#
#             Thalassemia  Result
# id
# Patient_02          3.0       1
# Patient_03          7.0       1
# Patient_07          3.0       1
# Patient_09          7.0       1
# Patient_10          7.0       1

# %%
df_no = df_patient[df_patient['Result'] == 0]
df_no.head()
# Out:
#             Age  Gender              Type  Blood_pressure  Cholesterol  \
# id
# Patient_01   63    Male    Typical angina             145          233
# Patient_04   37    Male  Non-anginal pain             130          250
# Patient_05   41  Female   Atypical angina             130          204
# Patient_06   56    Male   Atypical angina             120          236
# Patient_08   57  Female      Asymptomatic             120          354
#
#             Heartbeat  Thalassemia  Result
# id
# Patient_01        150          6.0       0
# Patient_04        187          3.0       0
# Patient_05        172          NaN       0
# Patient_06        178          3.0       0
# Patient_08        163          3.0       0

# %% [markdown]
# **Yêu cầu 4.3:**
# Lọc trong df_patient dưa ra danh sách bệnh nhân thỏa mãn yêu cầu sau:
# 1. Những người bị mắc bệnh đau tim và trên 70 tuổi
# 2. Người có giới tính Female, có huyết áp trên 170 mmhg nhưng không bị bệnh đau tim.
# 3. Những người có triệu chứng đau ngực là Typical angina, giới tính Male và bị bệnh đau tim.

# %%
#{HỌC VIÊN VIẾT CODE VÀO ĐÂY}
#1. Những người bị mắc bệnh đau tim và trên 70 tuổi

df_1 = df_yes[df_yes['Age'] > 70]
df_1.head()
# Out:
#              Age Gender          Type  Blood_pressure  Cholesterol  Heartbeat  \
# id
# Patient_161   77   Male  Asymptomatic             125          304        162
#
#              Thalassemia  Result
# id
# Patient_161          3.0       1

# %%
#2. Người có giới tính Female, có huyết áp trên 170 mmhg nhưng không bị bệnh đau tim.

df_2 = df_female[(df_female['Blood_pressure'] > 170) & (df_female['Result'] == 0)]
df_2.head()
# Out:
#              Age  Gender          Type  Blood_pressure  Cholesterol  \
# id
# Patient_201   64  Female  Asymptomatic             180          325
#
#              Heartbeat  Thalassemia  Result
# id
# Patient_201        154          3.0       0

# %%
#3. Những người có triệu chứng đau ngực là Typical angina, giới tính Male và bị bệnh đau tim.

df_3 = df_male[(df_male['Result'] == 1) & (df_male['Type'] == 'Typical angina')]
df_3.head()
# Out:
#              Age Gender            Type  Blood_pressure  Cholesterol  \
# id
# Patient_124   65   Male  Typical angina             138          282
# Patient_141   59   Male  Typical angina             170          288
# Patient_199   59   Male  Typical angina             160          273
# Patient_211   38   Male  Typical angina             120          231
# Patient_243   61   Male  Typical angina             134          234
#
#              Heartbeat  Thalassemia  Result
# id
# Patient_124        174          3.0       1
# Patient_141        159          7.0       1
# Patient_199        125          3.0       1
# Patient_211        182          7.0       1
# Patient_243        145          3.0       1

# %% [markdown]
# **Yêu cầu 4.4:** Xác định:
# 1. Chỉ số huyết áp (Blood_pressure) thấp nhất, cao nhất, trung bình, trung vị và độ lệch chuẩn của tập dữ liệu
# 2. Chỉ số nhịp tim (Heartbeat) thấp nhất, cao nhất, trung bình, trung vị và độ lệch chuẩn của tập dữ liệu

# %%
#{HỌC VIEN VIẾT CODE VÀO ĐÂY}
print('1. Chỉ số huyết áp:')
print('Min:', df_patient['Blood_pressure'].min())
print('Max:', df_patient['Blood_pressure'].max())
print('Mean:', df_patient['Blood_pressure'].mean())
print('Median:', df_patient['Blood_pressure'].median())
print('Std:', df_patient['Blood_pressure'].std())
# Out:
# 1. Chỉ số huyết áp:
# Min: 94
# Max: 200
# Mean: 131.68666666666667
# Median: 130.0
# Std: 17.682497692285477

# %%
print('2. Chỉ số nhịp tim')
print('Min:', df_patient['Heartbeat'].min())
print('Max:', df_patient['Heartbeat'].max())
print('Mean:', df_patient['Heartbeat'].mean())
print('Median:', df_patient['Heartbeat'].median())
print('Std:', df_patient['Heartbeat'].std())
# Out:
# 2. Chỉ số nhịp tim
# Min: 71
# Max: 202
# Mean: 149.56333333333333
# Median: 152.5
# Std: 22.818595118151098

# %% [markdown]
# **Yêu cầu 4.5: Xác định:**
# 1. Số giá trị khác nhau của thuộc tính Type
# 2. Vẽ đồ thị dạng cột thể hiện kết quả thống kê số lượng theo từng giá trị khác nhau của thuộc tính Type

# %%
#{HỌC VIÊN VIẾT CODE VÀO ĐÂY}

type_list = df_patient['Type'].dropna().unique()
print('1. Số giá trị khác nhau của thuộc tính Type:', len(type_list))
# Out:
# 1. Số giá trị khác nhau của thuộc tính Type: 4

# %%
#Vẽ biểu đồ:
import matplotlib.pyplot as plt

type_unique = df_patient['Type'].value_counts()

plt.bar(type_unique.index,type_unique.values)
plt.grid()
plt.show()
